# %% [markdown]
# # Troubleshooting Guide
#
# Common issues and how to fix them.
#
# ## Common Issues
#
# 1. **Connection errors**: Azure service credentials
# 2. **Processing failures**: Document format issues
# 3. **Empty results**: Configuration problems
# 4. **Performance issues**: Optimization needed
#
# See the full troubleshooting guide in the notebook.
