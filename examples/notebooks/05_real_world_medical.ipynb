# %% [markdown]
# # Real-World Example: Medical Device Manual Processing
#
# Process medical device manuals with product-specific metadata extraction.
#
# ## Use Case
#
# - Medical device manuals (pacemakers, defibrillators, etc.)
# - Product specifications
# - Procedure guides
# - Safety information
#
# ## Requirements
#
# - Extract product names, models, part numbers
# - Preserve tables (specifications, compatibility)
# - Handle multi-language manuals
# - Track document versions and dates

# %%
from ingestor import Pipeline, PipelineConfig
from ingestor.config import ChunkingMode, TableRenderMode
from dotenv import load_dotenv

load_dotenv()
print("✅ Medical device processing notebook ready")

# %% [markdown]
# ## Medical Device Configuration
#
# See full implementation in notebook file.
