# %% [markdown]
# # Performance Tuning Guide
#
# Optimize ingestor for large-scale document processing.
#
# ## Topics
#
# 1. **Batch size optimization**
# 2. **Concurrency settings**
# 3. **Chunking performance**
# 4. **Embedding optimization**
# 5. **Index tuning**
#
# See full guide in the notebook file.
